# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
# %cd /content/drive/MyDrive/YOLOv5_tracking
# Out:
# /content/drive/MyDrive/YOLOv5_tracking

# %%
# %pip install -qr yolov5/requirements.txt  # install dependencies

# %%
# !pip install pyyaml==5.4.1

# %%
import torch
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 1.10.0+cu111 CPU

# %%
#%cd /content/drive/MyDrive/YOLOv5_tracking/yolov5
#!python /content/drive/MyDrive/YOLOv5_tracking/yolov5/detect.py --weights yolov5m.pt  --img 640  --source /content/drive/MyDrive/YOLOv5-DeepSort/video.avi --save-txt --class 0 --line-thickness 1

# %cd /content/drive/MyDrive/YOLOv5_tracking/yolov5
#!python /content/drive/MyDrive/YOLOv5_tracking/yolov5/detect_track.py --weights yolov5m.pt  --img 640  --source /content/drive/MyDrive/YOLOv5-DeepSort/video.avi --save-txt --class 0 --line-thickness 1
# !python /content/drive/MyDrive/YOLOv5_tracking/yolov5/detect_track.py --weights yolov5m.pt  --img 640  --source /content/drive/MyDrive/YOLOv5_tracking/yolov5/tumofddd.avi --save-txt --class 0 --line-thickness 1
# Out:
# /content/drive/MyDrive/YOLOv5_tracking/yolov5
# detect_track: weights=['yolov5m.pt'], source=/content/drive/MyDrive/YOLOv5_tracking/yolov5/tumofddd.avi, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False, config_deepsort=deep_sort_pytorch/configs/deep_sort.yaml
# /content/drive/MyDrive/YOLOv5_tracking/yolov5/deep_sort_pytorch/utils/parser.py:24: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.update(yaml.load(fo.read()))
# Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# ...
